# %%
from difflib import SequenceMatcher

import edlib

# %%
target = "..."
a = "..."
b = "..."
c = "..."

# %%
[len(x) for x in [target, a, b, c]]

# %%
ret = edlib.align(a, b, mode="HW", task="path")

# %%
ret

# %%
ret = SequenceMatcher(None, a=b, b=c, autojunk=False)

# %%
# %timeit ret.find_longest_match(0, len(a), 0, len(b))

# %%
ret.find_longest_match(0, len(a), 0, len(b))

# %%
a[1598 : 1598 + 100]

# %%
b[1607 : 1607 + 100]

# %%
# %timeit longest_common_substring(a, b)
